# %%
# Install the Owlready2 library, which is used for ontology manipulation and reasoning.
# Upgrade it to the latest version if already installed.
# !pip install owlready2 transformers --upgrade

# Install the RDFLib library for working with RDF (Resource Description Framework) data,
# commonly used in ontology and semantic web tasks.
# !pip install rdflib

# Install additional libraries:
# - `torch`: PyTorch, a machine learning framework for deep learning models.
# - `networkx`: For working with graph data structures, often used in ontology matching.
# - `matplotlib`: A library for creating visualizations like graphs and plots.
# - `sentence-transformers`: For sentence-level embedding generation using pre-trained models.
# - `pandas`: For data manipulation and analysis.
# - `lxml`: A library for parsing and handling XML and HTML data, useful for processing ontologies.
# - `beautifulsoup4`: A library for web scraping and parsing HTML documents.
# !pip install torch networkx matplotlib sentence-transformers pandas lxml beautifulsoup4
# Out:
# Collecting owlready2
#   Downloading owlready2-0.47.tar.gz (27.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 33.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Collecting transformers
#   Downloading transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 37.5 MB/s eta 0:00:00
# Building wheels for collected packages: owlready2
#   Building wheel for owlready2 (pyproject.toml) ... done
#   Created wheel for owlready2: filename=owlready2-0.47-cp310-cp310-linux_x86_64.whl size=24075199 sha256=62aa937e1ff7056009f8c4327c1d11644ddef39238e6bf8eede73b220d524bde
#   Stored in directory: /root/.cache/pip/wheels/27/3e/ba/4171c4b10bba9fe1774fbf8fcf794de889e636ce64ad83a533
# Successfully built owlready2
# Installing collected packages: owlready2, transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.2
#     Uninstalling transformers-4.46.2:
#       Successfully uninstalled transformers-4.46.2
# Successfully installed owlready2-0.47 transformers-4.46.3
# Collecting rdflib
#   Downloading rdflib-7.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting isodate<1.0.0,>=0.7.2 (from rdflib)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.2.0)
# Downloading rdflib-7.1.1-py3-none-any.whl (562 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.4/562.4 kB 17.0 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.7.2 rdflib-7.1.1
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (5.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.46.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)

# %%
# Importing necessary libraries for ontology manipulation, data processing, machine learning, and graph analysis

# JSON library for working with JSON data, often used for saving and loading structured data like ontology metadata.
import json

# `owlready2` for working with OWL ontologies, including loading, querying, and reasoning.
from owlready2 import *

# `pandas` for data manipulation and analysis, especially useful for handling tabular data.
import pandas as pd

# `numpy` for numerical computations, used in operations like matrix manipulations and array processing.
import numpy as np

# Importing `json` again (already imported above, this is redundant and can be removed).
import json

# PyTorch library for building and training machine learning models.
import torch

# `os` module for interacting with the operating system, e.g., file and directory operations.
import os

# AutoTokenizer and AutoModel from Hugging Face Transformers library for tokenizing text and loading pre-trained transformer models.
from transformers import AutoTokenizer, AutoModel

# `Graph`, `Namespace`, and `URIRef` from RDFLib for working with RDF graphs and resources.
from rdflib import Graph, Namespace, URIRef

# `defaultdict` from collections module, useful for creating dictionaries with default values.
from collections import defaultdict

# Importing typing utilities for type hints (e.g., specifying function parameter types like `List`).
from typing import List

# `math` library for mathematical functions, such as calculating logarithms or trigonometric operations.
import math

# CSV library for reading and writing CSV (Comma-Separated Values) files.
import csv

# Importing `Graph` and `Namespace` again from RDFLib (redundant and can be removed).
from rdflib import Graph, Namespace

# `BeautifulSoup` from `bs4` for parsing HTML or XML documents, often used in web scraping or ontology enrichment tasks.
from bs4 import BeautifulSoup

# `etree` from lxml for advanced XML and HTML parsing and processing.
from lxml import etree

# `pickle` for serializing and deserializing Python objects, often used to save or load models, embeddings, or intermediate results.
import pickle

# `networkx` for creating and analyzing graph-based data structures, useful in ontology matching and graph neural networks.
import networkx as nx

# %%
# Class to process and structure ontology text data
class OntoText:
    def __init__(self, data):
        """
        Initialize the OntoText class with data and process it.
        :param data: Dictionary with concept IDs as keys and lists of labels/synonyms as values.
        """
        self.data = data  # JSON data with concept IDs and their lists of labels/synonyms
        self.texts = defaultdict(list)  # Stores processed labels/synonyms for each concept
        self.class2idx = {}  # Mapping from concept IDs to unique indices
        self.idx2class = {}  # Mapping from indices back to concept IDs
        self.extract_texts()  # Extract and preprocess texts
        self.create_class_idx_mappings()  # Create mappings for concept IDs and indices

    def extract_texts(self):
        """
        Extracts labels/synonyms from the input data and converts them to lowercase.
        """
        for concept_id, labels in self.data.items():
            # Add all entries in the list as lowercase labels/synonyms
            for label in labels:
                self.texts[concept_id].append(label.lower())

    def create_class_idx_mappings(self):
        """
        Creates mappings between concept IDs and unique numerical indices.
        """
        for idx, concept_id in enumerate(self.texts.keys()):
            self.class2idx[concept_id] = idx
            self.idx2class[idx] = concept_id


# Class to construct an inverted index for ontology text data
class OntoInvertedIndex:
    def __init__(self, ontotext: OntoText, tokenizer_path: str, cut: int = 0):
        """
        Initialize the OntoInvertedIndex class.
        :param ontotext: An OntoText object containing processed ontology data.
        :param tokenizer_path: Path to a pre-trained tokenizer (e.g., BioBERT tokenizer).
        :param cut: Minimum token length to include in the index.
        """
        self.ontotext = ontotext  # OntoText object for processed ontology data
        self.tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)  # Load tokenizer
        self.cut = cut  # Minimum token length to include in the index
        self.index = self.construct_index()  # Build the inverted index

    def tokenize(self, texts: List[str]) -> List[str]:
        """
        Tokenizes a list of texts using the pre-trained tokenizer.
        :param texts: List of strings to tokenize.
        :return: List of tokens.
        """
        return [token for text in texts for token in self.tokenizer.tokenize(text)]

    def construct_index(self):
        """
        Constructs an inverted index mapping tokens to concept indices.
        :return: A dictionary with tokens as keys and lists of concept indices as values.
        """
        index = defaultdict(list)  # Initialize an empty inverted index
        for concept_id, labels in self.ontotext.texts.items():
            tokens = self.tokenize(labels)  # Tokenize all labels/synonyms
            for token in tokens:
                if len(token) > self.cut:  # Include tokens that meet the length threshold
                    index[token].append(self.ontotext.class2idx[concept_id])  # Map token to concept index
        return index


# Class to manage source and target ontology data and generate mapping candidates
class OntoBox:
    def __init__(self, src_data, tgt_data, tokenizer_path="cambridgeltl/SapBERT-UMLS-2020AB-all-lang-from-XLMR", cut=0):
        """
        Initialize the OntoBox class with source and target ontologies.
        :param src_data: Source ontology data (concept IDs and labels/synonyms).
        :param tgt_data: Target ontology data (concept IDs and labels/synonyms).
        :param tokenizer_path: Path to a pre-trained tokenizer.
        :param cut: Minimum token length for the inverted index.
        """
        self.src_ontotext = OntoText(src_data)  # Process source ontology data
        self.tgt_ontotext = OntoText(tgt_data)  # Process target ontology data
        # Create inverted indices for both source and target ontologies
        self.src_onto_index = OntoInvertedIndex(self.src_ontotext, tokenizer_path, cut=cut)
        self.tgt_onto_index = OntoInvertedIndex(self.tgt_ontotext, tokenizer_path, cut=cut)

    def select_candidates(self, concept_texts: List[str], candidate_limit: int = 10):
        """
        Select candidate concepts from the target ontology based on token overlap and IDF scores.
        :param concept_texts: List of source concept labels/synonyms to find matches for.
        :param candidate_limit: Maximum number of candidates to return.
        :return: List of candidate concept IDs from the target ontology.
        """
        candidate_pool = defaultdict(lambda: 0)  # Pool of candidate scores
        tokens = self.tgt_onto_index.tokenize(concept_texts)  # Tokenize source concept texts
        D = len(self.tgt_ontotext.class2idx)  # Total number of target concepts

        for token in tokens:
            potential_candidates = self.tgt_onto_index.index.get(token, [])  # Get concepts containing the token
            if not potential_candidates:
                continue
            # Calculate Inverse Document Frequency (IDF) for the token
            idf = math.log10(D / len(potential_candidates))
            for class_id in potential_candidates:
                candidate_pool[class_id] += idf  # Accumulate IDF scores for candidates

        # Sort candidates by score (descending) and limit to the specified number
        sorted_candidates = sorted(candidate_pool.items(), key=lambda x: x[1], reverse=True)[:candidate_limit]
        # Retrieve the original concept IDs for the selected candidates
        selected_classes = [self.tgt_ontotext.idx2class[c[0]] for c in sorted_candidates]

        return selected_classes

    def generate_candidates(self, candidate_limit: int = 10):
        """
        Generate candidate mappings between source and target ontologies.
        :param candidate_limit: Maximum number of candidates per source concept.
        :return: List of candidate pairs (source concept ID, target concept ID).
        """
        candidate_pairs = []
        # Iterate through all source concepts
        for src_id, text_dict in self.src_ontotext.texts.items():
            src_texts = text_dict  # Use all source labels/synonyms
            candidates = self.select_candidates(src_texts, candidate_limit)  # Get target candidates
            # Pair each source concept with its selected target candidates
            for tgt_id in candidates:
                candidate_pairs.append((src_id, tgt_id))

        return candidate_pairs

# %%
def clean_json_by_alignment(file_path, json_path, output_path):
    """
    Cleans a JSON file by removing concepts marked as not used for alignment.

    Args:
        file_path (str): Path to the OWL file (ontology in RDF/XML format).
        json_path (str): Path to the JSON file to clean.
        output_path (str): Path to save the cleaned JSON file.
    """
    # Initialize the RDF graph
    g = Graph()
    # Parse the OWL file into the RDF graph
    g.parse(file_path, format='xml')

    # Define namespaces for the RDF graph
    ALIGNMENT_NS = Namespace("http://oaei.ontologymatching.org/bio-ml/ann/")
    # Define the specific property used to indicate alignment usability
    USE_IN_ALIGNMENT = URIRef("http://oaei.ontologymatching.org/bio-ml/ann/use_in_alignment")

    # Load the JSON file containing concepts and labels/synonyms
    with open(json_path, "r") as f:
        data = json.load(f)

    # Set to hold valid IRIs (concepts marked as usable for alignment)
    valid_iris = set()

    # Iterate over all subjects (classes) in the ontology
    for subj in g.subjects(predicate=None):
        # Check if the class has a `use_in_alignment` annotation
        alignment_value = g.value(subject=subj, predicate=USE_IN_ALIGNMENT)
        # Include the IRI if `use_in_alignment` is not present or is set to "true"
        if alignment_value is None or str(alignment_value).lower() == "true":
            valid_iris.add(str(subj))

    # Filter the JSON data to include only IRIs present in the valid set
    cleaned_data = {iri: labels for iri, labels in data.items() if iri in valid_iris}

    # Save the cleaned JSON data to the specified output file
    with open(output_path, "w") as f:
        json.dump(cleaned_data, f, indent=4, ensure_ascii=False)

    # Print summary information about the cleaning process
    print(f"Cleaned JSON file saved to: {output_path}")
    print(f"Excluded concepts: {len(data) - len(cleaned_data)}")
    print(f"Remaining concepts: {len(cleaned_data)}")

# %%
def clean_json_using_tsv(json_file_path, tsv_file_path, output_json_path):
    """
    Cleans a JSON file by removing entries not present in the 'SrcEntity' column of a TSV file.

    Args:
    - json_file_path (str): Path to the JSON file to be cleaned.
    - tsv_file_path (str): Path to the TSV file containing valid 'SrcEntity' entries.
    - output_json_path (str): Path to save the cleaned JSON file.

    Returns:
    - None
    """
    # Load the JSON file
    with open(json_file_path, 'r') as json_file:
        json_data = json.load(json_file)

    # Load the TSV file and extract 'SrcEntity' column as a set
    tsv_data = pd.read_csv(tsv_file_path, sep="\t")
    valid_entities = set(tsv_data['SrcEntity'])

    # Filter JSON entries to retain only those keys present in 'SrcEntity'
    original_count = len(json_data)
    cleaned_data = {key: value for key, value in json_data.items() if key in valid_entities}
    cleaned_count = len(cleaned_data)

    # Calculate excluded entries
    excluded_count = original_count - cleaned_count

    # Save the cleaned JSON data
    with open(output_json_path, 'w') as output_file:
        json.dump(cleaned_data, output_file, indent=4)

    print(f"Cleaned JSON file saved to {output_json_path}")
    print(f"Original entries: {original_count}")
    print(f"Remaining entries: {cleaned_count}")
    print(f"Excluded entries: {excluded_count}")

# %%
# Function to build indexed dictionary
def build_indexed_dict(file_path):
    # Load the JSON file
    with open(file_path, 'r') as file:
        data = json.load(file)

    # Create a new dictionary with numeric indexes for each key (URI)
    indexed_dict = {key: index for index, key in enumerate(data.keys())}

    return indexed_dict

# %%
# Function to encode URIs using the provided indexed dictionaries
def encode_uris(row, source_dict, target_dict):
    """
    Encodes URIs from a DataFrame row using provided dictionaries.

    Args:
        row (pd.Series): A single row from a DataFrame containing `SrcEntity` and `TgtEntity` columns.
        source_dict (dict): Dictionary mapping source URIs to their integer encodings.
        target_dict (dict): Dictionary mapping target URIs to their integer encodings.

    Returns:
        pd.Series: A series containing the encoded source and target URIs as integers.
    """
    # Extract source and target URIs from the row
    uri_1, uri_2 = row['SrcEntity'], row['TgtEntity']

    # Encode the source URI using the source dictionary, defaulting to -1 if not found
    encoded_uri_1 = source_dict.get(uri_1, -1)  # -1 indicates a missing value
    # Encode the target URI using the target dictionary, defaulting to -1 if not found
    encoded_uri_2 = target_dict.get(uri_2, -1)  # -1 indicates a missing value

    # Ensure the encoded URIs are integers (in case they are stored as floats or other types)
    return pd.Series([int(encoded_uri_1), int(encoded_uri_2)])

# %%
# Importing the 'drive' module from Google Colab to interact with Google Drive
from google.colab import drive

# Mount the user's Google Drive to the Colab environment
# After running this, a link will appear to authorize access, and Google Drive will be mounted at '/content/gdrive'
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Define the source ontology name
src_ent = "snomed.pharm"

# Define the target ontology name
tgt_ent = "ncit.pharm"

# Define the task name for this ontology matching process
task = "pharm"

# %%
dir = "/content/gdrive/My Drive/BioGITOM-VLDB"

# Define the directory for the dataset containing source and target ontologies
dataset_dir = f"{dir}/Datasets/{task}"

# Define the data directory for storing embeddings, adjacency matrices, and related files
data_dir = f"{dir}/{task}/Data"

# %%
# Load the Source ontology (OMIM) using the Ontology class from DeepOnto
src_onto_path = f"{dataset_dir}/{src_ent}.owl"

# Load the Target ontology (ORDO) using the Ontology class from DeepOnto
tgt_onto_path = f"{dataset_dir}/{tgt_ent}.owl"

# Define the file path for the JSON file containing the Source ontology (OMIM) class labels
src_class_path = f"{data_dir}/{src_ent}_classes2.json"

# Define the file path for the JSON file containing the Target ontology (ORDO) class labels
tgt_class_path = f"{data_dir}/{tgt_ent}_classes.json"

# Define the file path for the candidate mappings between Source to Target entities
Candidates = f"{data_dir}/{task}.candidades2.csv"

# Define the file path for the cleaned JSON file containing source class labels used for testing
src_class_cleaned_test = f"{data_dir}/{src_ent}_cleaned_test_classes2.json"  # Cleaned test classes for source

# Define the file path for the TSV file containing reference equivalences for testing
tsv_file_path = f"{dataset_dir}/refs_equiv/test.tsv"  # Reference file with equivalences for evaluation

# Define the file path for the cleaned and encoded JSON file containing source class labels
src_class_cleaned = f"{data_dir}/{src_ent}_cleaned_classes2.json"  # Cleaned and encoded classes for source

# Define the file path for the cleaned JSON file containing target class labels
tgt_class_cleaned = f"{data_dir}/{tgt_ent}_cleaned_classes2.json"  # Cleaned classes for target

# Define the file paths for candidate mappings
candidate_path = f"{data_dir}/candidates_cleaned2.csv"  # CSV file with candidate mappings

candidate_encoded_path = f"{data_dir}/{task}_candidates_cleaned_encoded2.csv"  # Encoded candidate mappings

candidates_cleaned_encoded_combined = f"{data_dir}/{task}_candidates_cleaned_combined_encoded2.csv"

candidates_cleaned_encoded_enriched = f"{data_dir}/{task}_candidates_cleaned_enriched_encoded2.csv"

# %% [markdown]
# # **Cleaning**

# %%
# Clean the JSON file for the source ontology
# This removes unnecessary concepts from the source ontology JSON file (`src_class_path`)
# based on alignment annotations in the source ontology OWL file (`src_onto_path`).
# The cleaned JSON is saved to `src_class_cleaned_encodage`.
clean_json_by_alignment(src_onto_path, src_class_path, src_class_cleaned)

# Clean the JSON file for the target ontology
# Similarly, this removes unnecessary concepts from the target ontology JSON file (`tgt_class_path`)
# based on alignment annotations in the target ontology OWL file (`tgt_onto_path`).
# The cleaned JSON is saved to `tgt_class_cleaned`.
clean_json_by_alignment(tgt_onto_path, tgt_class_path, tgt_class_cleaned)
# Out:
# Cleaned JSON file saved to: /content/gdrive/My Drive/BioGITOM-VLDB//pharm/Data/snomed.pharm_cleaned_classes2.json
# Excluded concepts: 13456
# Remaining concepts: 16190
# Cleaned JSON file saved to: /content/gdrive/My Drive/BioGITOM-VLDB//pharm/Data/ncit.pharm_cleaned_classes2.json
# Excluded concepts: 6886
# Remaining concepts: 15347

# %%
# Call the function to clean the source JSON file based on the TSV file
# The `clean_json_using_tsv` function uses the reference equivalence file (`tsv_file_path`)
# to further filter the cleaned source JSON file (`src_class_cleaned_encodage`).
# The resulting JSON file, containing only relevant concepts for testing, is saved to `src_class_cleaned_test`.
clean_json_using_tsv(src_class_cleaned, tsv_file_path, src_class_cleaned_test)
# Out:
# Cleaned JSON file saved to /content/gdrive/My Drive/BioGITOM-VLDB//pharm/Data/snomed.pharm_cleaned_test_classes2.json
# Original entries: 16190
# Remaining entries: 3989
# Excluded entries: 12201

# %% [markdown]
# # **Candidates Generation**

# %%
# Load JSON files for both source and target ontologies
with open(src_class_cleaned_test, 'r') as f:
    src_data = json.load(f)

# Assuming the target data JSON file path is correct
with open(tgt_class_cleaned, 'r') as f:
    tgt_data = json.load(f)

# %%
# Instantiate OntoBox and generate candidate pairs
ontobox = OntoBox(src_data, tgt_data)
candidates = ontobox.generate_candidates()

# Print candidates for verification
for src, tgt in candidates:
    print(f"SrcEntity: {src}, TgtEntity: {tgt}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C71634
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C62501
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C152703
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C166948
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76603
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C150559
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C128894
# SrcEntity: http://snomed.info/id/441995009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C83768
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C81501
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C195
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C904
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1155
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87657
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87712
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2352
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C125632
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76672
# SrcEntity: http://snomed.info/id/89775008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C422
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47540
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C81648
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C65754
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C433
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C162757
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1105
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1524
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C83953
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47579
# SrcEntity: http://snomed.info/id/129490002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63670
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C175185
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C158505
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C152437
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C97714
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C169048
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C911
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/715378000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C148516
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C900
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95327
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C758
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C362
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61634
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C73820
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C81116
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1022
# SrcEntity: http://snomed.info/id/63318000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61595
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1528
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1670
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87458
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C869
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C156698
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C97315
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1333
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C97314
# SrcEntity: http://snomed.info/id/387582001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C28822
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C66722
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84166
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C166478
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1588
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84116
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2337
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1360
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C174575
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47751
# SrcEntity: http://snomed.info/id/716222009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C154674
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1258
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C321
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C28822
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95195
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1424
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95225
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C664
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C74379
# SrcEntity: http://snomed.info/id/67639003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95316
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95311
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87582
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87748
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C289
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C29508
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76668
# SrcEntity: http://snomed.info/id/421308003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C176813
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C422
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1181
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C642
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C73051
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2415
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C160606
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C65848
# SrcEntity: http://snomed.info/id/320759006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C172098
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C627
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C362
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C664
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1583
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1326
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1258
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C773
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C405
# SrcEntity: http://snomed.info/id/36380001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C869
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47698
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C120570
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C77835
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C80853
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C770
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C118371
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C79758
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C66498
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84248
# SrcEntity: http://snomed.info/id/411297004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84249
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1647
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C90743
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C72943
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C758
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1181
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C90701
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C65857
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47697
# SrcEntity: http://snomed.info/id/703515001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C74545
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C318
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C362
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2706
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C411
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C504
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95225
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1460
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47422
# SrcEntity: http://snomed.info/id/398837005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76261
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1819
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1326
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C73805
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84169
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C83769
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C96746
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1555
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1197
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1403
# SrcEntity: http://snomed.info/id/426324001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C66554
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1071
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47751
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76306
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C176963
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C999
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84172
# SrcEntity: http://snomed.info/id/108816003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C877
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C66114
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C422
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63950
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1155
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C644
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C647
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C82310
# SrcEntity: http://snomed.info/id/400745007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1154
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C81418
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C505
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C422
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C75112
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1189
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C504
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C513
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95195
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63482
# SrcEntity: http://snomed.info/id/387451002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C102554
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C78825
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C758
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C970
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C60772
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C162855
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2579
# SrcEntity: http://snomed.info/id/709283009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C116877
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C970
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C758
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C504
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87629
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C766
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C29115
# SrcEntity: http://snomed.info/id/318706009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C175305
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2194
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61948
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95718
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C643
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C174591
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C124995
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C98283
# SrcEntity: http://snomed.info/id/420681006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84166
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47715
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C96882
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C834
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C758
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C408
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C80566
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C81001
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1136
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C405
# SrcEntity: http://snomed.info/id/22192002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63678
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173363
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2828
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1413
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C82676
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1381
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C176813
# SrcEntity: http://snomed.info/id/108779005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C459
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C362
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C664
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C966
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1258
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C627
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C405
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1190
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1843
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/782160004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C75248
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C320
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C321
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1647
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84460
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1374
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C99154
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C38709
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C62013
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C151930
# SrcEntity: http://snomed.info/id/395744006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C160712
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C405
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C175294
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76426
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C77409
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C422
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C45845
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61527
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1027
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61499
# SrcEntity: http://snomed.info/id/96105002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61621
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C611
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1282
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95766
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47777
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C65875
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C171348
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C758
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C291
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C970
# SrcEntity: http://snomed.info/id/717169003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1189
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C38717
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C376
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C505
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1282
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1155
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C65745
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95196
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1744
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87774
# SrcEntity: http://snomed.info/id/385549000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1208
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C73596
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C97985
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C83909
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C627
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C289
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1127
# SrcEntity: http://snomed.info/id/349819003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C97989
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C422
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C966
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C770
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C337
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C65257
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95327
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C126913
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C869
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1362
# SrcEntity: http://snomed.info/id/17908000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1076
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C156895
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C115977
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84842
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2502
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C118948
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133821
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C29080
# SrcEntity: http://snomed.info/id/782991009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C138160
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C855
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C66434
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61439
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1762
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C975
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2460
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95713
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C176969
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1220
# SrcEntity: http://snomed.info/id/387055000, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C73032
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C250
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C29710
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C171714
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C28197
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C273
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C156461
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C267
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C411
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C163758
# SrcEntity: http://snomed.info/id/787993002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C169048
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84166
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C405
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C80657
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C480
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1105
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C105950
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C84157
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C120561
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87289
# SrcEntity: http://snomed.info/id/415542004, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C65745
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C157539
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C157538
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47509
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C157408
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C157404
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2388
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C157537
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C121961
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1395
# SrcEntity: http://snomed.info/id/404855005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C627
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C773
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C664
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1583
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1326
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C362
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1258
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76668
# SrcEntity: http://snomed.info/id/782604006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C966
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C71792
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C74575
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C758
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C75277
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C627
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C29104
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C550
# SrcEntity: http://snomed.info/id/48899009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C549
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C627
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C362
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C773
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1583
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C664
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1326
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1258
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47426
# SrcEntity: http://snomed.info/id/108924009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C966
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47444
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C362
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C72168
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61672
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87262
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C627
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C81406
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C81405
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61805
# SrcEntity: http://snomed.info/id/71668006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C132291
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47640
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C75110
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C66253
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C75108
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C29165
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1843
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C156452
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95830
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/412260006, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1326
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47633
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61857
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C148531
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1155
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C82492
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C162629
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C83768
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C73327
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C68462
# SrcEntity: http://snomed.info/id/363571003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C38717
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1953
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63662
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1313
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C77155
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1068
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C48397
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C28816
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C74371
# SrcEntity: http://snomed.info/id/96351007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C80267
# ...
# SrcEntity: http://snomed.info/id/398944002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C29244
# SrcEntity: http://snomed.info/id/398944002, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76468
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C167001
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1528
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C159496
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C175461
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C162996
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C172928
# SrcEntity: http://snomed.info/id/896965008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C173999
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C405
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C154440
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87334
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C83628
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C195
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87341
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95229
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C80300
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C175294
# SrcEntity: http://snomed.info/id/703585009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C83742
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C855
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C74212
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1762
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1155
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87359
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C405
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1406
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2460
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1367
# SrcEntity: http://snomed.info/id/702401005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95713
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C680
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C48006
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C148531
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C643
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C166529
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C83768
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1435
# SrcEntity: http://snomed.info/id/11847009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1739
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61564
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2104
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47715
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C422
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C157025
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76266
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C504
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95195
# SrcEntity: http://snomed.info/id/698843001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C933
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C75095
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63662
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C242
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95934
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C176813
# SrcEntity: http://snomed.info/id/411361005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C459
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C664
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C362
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47428
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C405
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1258
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C249
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C148455
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C157231
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C982
# SrcEntity: http://snomed.info/id/386979007, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C966
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C773
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C627
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C966
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1258
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C83628
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1583
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1326
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C664
# SrcEntity: http://snomed.info/id/24261009, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C362
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C28580
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1222
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C171425
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87420
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1258
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1788
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C869
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1486
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C90763
# SrcEntity: http://snomed.info/id/412296005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C131607
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47503
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63662
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1416
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2265
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C648
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C65496
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1262
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C627
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C509
# SrcEntity: http://snomed.info/id/385572003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C337
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C74412
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C95327
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C236
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C72077
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C176813
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C459
# SrcEntity: http://snomed.info/id/703372005, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C142605
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47478
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1282
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C408
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C422
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47432
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C642
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C47422
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61706
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C76674
# SrcEntity: http://snomed.info/id/19499001, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1181
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C2388
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C72839
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1395
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C170836
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1200
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42639
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C67504
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C133274
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C153327
# SrcEntity: http://snomed.info/id/704476003, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C122036
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C48014
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C504
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1465
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C48015
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C647
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C769
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C766
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C563
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C793
# SrcEntity: http://snomed.info/id/372697008, TgtEntity: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C1008

# %%
# Convert candidates to a DataFrame
candidate_df = pd.DataFrame(candidates, columns=["SrcEntity", "TgtEntity"])

# Add an incremental "ID" column starting from 0
candidate_df.insert(0, "ID", range(len(candidate_df)))

# Save the DataFrame to a CSV file
candidate_df.to_csv(candidate_path, index=False)

print(f"Candidates saved successfully to {candidate_path}")
# Out:
# Candidates saved successfully to /content/gdrive/My Drive/BioGITOM-VLDB//pharm/Data/candidates_cleaned2.csv

# %%
# Load Source and Target and ORDO class indexed dictionaries
indexed_dict_source = build_indexed_dict(src_class_path)
indexed_dict_target = build_indexed_dict(tgt_class_path)

# %%
# Create a DataFrame from the list of candidate mappings
# The `candidates` variable is expected to be a list of tuples containing source and target entities.
candidate_df = pd.DataFrame(candidates, columns=["SrcEntity", "TgtEntity"])

# Apply the `encode_uris` function to encode the source and target URIs into integers
# The `source_dict` and `target_dict` are dictionaries mapping URIs to their integer indices.
# This ensures the URIs are replaced with numeric representations in the DataFrame.
candidate_df[["SrcEntity", "TgtEntity"]] = candidate_df.apply(
    encode_uris, axis=1, source_dict=indexed_dict_source, target_dict=indexed_dict_target
)

# Add an ID column to the DataFrame
# The ID column is a unique identifier for each candidate pair, starting from 1.
candidate_df["ID"] = candidate_df.index + 1

# Reorder the columns for the final output: ID, SrcEntity, TgtEntity
# Save the DataFrame to a CSV file with the specified `candidate_encoded_path`.
# The `quoting=csv.QUOTE_NONNUMERIC` ensures that numeric values are not enclosed in quotes.
candidate_df[["ID", "SrcEntity", "TgtEntity"]].to_csv(candidate_encoded_path, index=False, quoting=csv.QUOTE_NONNUMERIC)

# Print confirmation message with the file path
print(f"Candidates saved to {candidate_encoded_path}")
# Out:
# Candidates saved to /content/gdrive/My Drive/BioGITOM-VLDB//pharm/Data/pharm_candidates_cleaned_encoded2.csv

# %%
# Load the existing candidates file
candidates_df = pd.read_csv(candidate_encoded_path)

# Load the source file with additional candidates
additional_candidates_df = pd.read_csv(Candidates)

# Concatenate the two DataFrames
combined_df = pd.concat([candidates_df, additional_candidates_df])

# Remove duplicate rows based on SrcEntity and TgtEntity columns
combined_df = combined_df.drop_duplicates(subset=["SrcEntity", "TgtEntity"])

# Save the combined DataFrame back to a CSV file
combined_df.to_csv(candidates_cleaned_encoded_combined, index=False, quoting=csv.QUOTE_NONNUMERIC)

print(f"Combined candidates saved to {candidates_cleaned_encoded_combined}")
# Out:
# Combined candidates saved to /content/gdrive/My Drive/BioGITOM-VLDB/pharm/Data/pharm_candidates_cleaned_combined_encoded2.csv

# %%
# Load the existing candidates file
candidates_df = pd.read_csv(candidate_encoded_path)

# Load the source file with additional candidates
additional_candidates_df = pd.read_csv(Candidates)

# Identify entries in the additional candidates file that are not in the existing candidates file
# Assuming 'SrcEntity' and 'TgtEntity' columns are used to uniquely identify rows
new_entries = additional_candidates_df[
    ~additional_candidates_df.set_index(["SrcEntity", "TgtEntity"]).index.isin(
        candidates_df.set_index(["SrcEntity", "TgtEntity"]).index
    )
]

# Append the new entries to the original candidates DataFrame
enriched_candidates_df = pd.concat([candidates_df, new_entries])

# Save the enriched DataFrame to a new file or overwrite the original file
enriched_candidates_df.to_csv(candidates_cleaned_encoded_enriched, index=False, quoting=csv.QUOTE_NONNUMERIC)

print(f"Enriched candidates saved to {candidates_cleaned_encoded_enriched}")
# Out:
# Enriched candidates saved to /content/gdrive/My Drive/BioGITOM-VLDB/pharm/Data/pharm_candidates_cleaned_enriched_encoded2.csv

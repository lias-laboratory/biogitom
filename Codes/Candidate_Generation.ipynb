# %%
# Install the Owlready2 library, which is used for ontology manipulation and reasoning.
# Upgrade it to the latest version if already installed.

# Install the RDFLib library for working with RDF (Resource Description Framework) data,
# commonly used in ontology and semantic web tasks.

# Install additional libraries:
# - `torch`: PyTorch, a machine learning framework for deep learning models.
# - `networkx`: For working with graph data structures, often used in ontology matching.
# - `matplotlib`: A library for creating visualizations like graphs and plots.
# - `sentence-transformers`: For sentence-level embedding generation using pre-trained models.
# - `pandas`: For data manipulation and analysis.
# - `lxml`: A library for parsing and handling XML and HTML data, useful for processing ontologies.
# - `beautifulsoup4`: A library for web scraping and parsing HTML documents.
# Out:
# Collecting owlready2
#   Downloading owlready2-0.47.tar.gz (27.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 18.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Collecting transformers
#   Downloading transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 25.8 MB/s eta 0:00:00
# Building wheels for collected packages: owlready2
#   Building wheel for owlready2 (pyproject.toml) ... done
#   Created wheel for owlready2: filename=owlready2-0.47-cp310-cp310-linux_x86_64.whl size=24075204 sha256=bc58693620ed012b9338f5f8c60382a7fb99443ef51c5d7d16cecfc9f1924e3d
#   Stored in directory: /root/.cache/pip/wheels/27/3e/ba/4171c4b10bba9fe1774fbf8fcf794de889e636ce64ad83a533
# Successfully built owlready2
# Installing collected packages: owlready2, transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.2
#     Uninstalling transformers-4.46.2:
#       Successfully uninstalled transformers-4.46.2
# Successfully installed owlready2-0.47 transformers-4.46.3
# Collecting rdflib
#   Downloading rdflib-7.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting isodate<1.0.0,>=0.7.2 (from rdflib)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.2.0)
# Downloading rdflib-7.1.1-py3-none-any.whl (562 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.4/562.4 kB 15.1 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.7.2 rdflib-7.1.1
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (5.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.46.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)

# %%
# Importing necessary libraries for ontology manipulation, data processing, machine learning, and graph analysis

# JSON library for working with JSON data, often used for saving and loading structured data like ontology metadata.
import json

# `owlready2` for working with OWL ontologies, including loading, querying, and reasoning.
from owlready2 import *

# `pandas` for data manipulation and analysis, especially useful for handling tabular data.
import pandas as pd

# `numpy` for numerical computations, used in operations like matrix manipulations and array processing.
import numpy as np

# Importing `json` again (already imported above, this is redundant and can be removed).
import json

# PyTorch library for building and training machine learning models.
import torch

# `os` module for interacting with the operating system, e.g., file and directory operations.
import os

# AutoTokenizer and AutoModel from Hugging Face Transformers library for tokenizing text and loading pre-trained transformer models.
from transformers import AutoTokenizer, AutoModel

# `Graph`, `Namespace`, and `URIRef` from RDFLib for working with RDF graphs and resources.
from rdflib import Graph, Namespace, URIRef

# `defaultdict` from collections module, useful for creating dictionaries with default values.
from collections import defaultdict

# Importing typing utilities for type hints (e.g., specifying function parameter types like `List`).
from typing import List

# `math` library for mathematical functions, such as calculating logarithms or trigonometric operations.
import math

# CSV library for reading and writing CSV (Comma-Separated Values) files.
import csv

# Importing `Graph` and `Namespace` again from RDFLib (redundant and can be removed).
from rdflib import Graph, Namespace

# `BeautifulSoup` from `bs4` for parsing HTML or XML documents, often used in web scraping or ontology enrichment tasks.
from bs4 import BeautifulSoup

# `etree` from lxml for advanced XML and HTML parsing and processing.
from lxml import etree

# `pickle` for serializing and deserializing Python objects, often used to save or load models, embeddings, or intermediate results.
import pickle

# `networkx` for creating and analyzing graph-based data structures, useful in ontology matching and graph neural networks.
import networkx as nx

# %%
# Class to process and structure ontology text data
class OntoText:
    def __init__(self, data):
        """
        Initialize the OntoText class with data and process it.
        :param data: Dictionary with concept IDs as keys and lists of labels/synonyms as values.
        """
        self.data = data  # JSON data with concept IDs and their lists of labels/synonyms
        self.texts = defaultdict(list)  # Stores processed labels/synonyms for each concept
        self.class2idx = {}  # Mapping from concept IDs to unique indices
        self.idx2class = {}  # Mapping from indices back to concept IDs
        self.extract_texts()  # Extract and preprocess texts
        self.create_class_idx_mappings()  # Create mappings for concept IDs and indices

    def extract_texts(self):
        """
        Extracts labels/synonyms from the input data and converts them to lowercase.
        """
        for concept_id, labels in self.data.items():
            # Add all entries in the list as lowercase labels/synonyms
            for label in labels:
                self.texts[concept_id].append(label.lower())

    def create_class_idx_mappings(self):
        """
        Creates mappings between concept IDs and unique numerical indices.
        """
        for idx, concept_id in enumerate(self.texts.keys()):
            self.class2idx[concept_id] = idx
            self.idx2class[idx] = concept_id


# Class to construct an inverted index for ontology text data
class OntoInvertedIndex:
    def __init__(self, ontotext: OntoText, tokenizer_path: str, cut: int = 0):
        """
        Initialize the OntoInvertedIndex class.
        :param ontotext: An OntoText object containing processed ontology data.
        :param tokenizer_path: Path to a pre-trained tokenizer (e.g., BioBERT tokenizer).
        :param cut: Minimum token length to include in the index.
        """
        self.ontotext = ontotext  # OntoText object for processed ontology data
        self.tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)  # Load tokenizer
        self.cut = cut  # Minimum token length to include in the index
        self.index = self.construct_index()  # Build the inverted index

    def tokenize(self, texts: List[str]) -> List[str]:
        """
        Tokenizes a list of texts using the pre-trained tokenizer.
        :param texts: List of strings to tokenize.
        :return: List of tokens.
        """
        return [token for text in texts for token in self.tokenizer.tokenize(text)]

    def construct_index(self):
        """
        Constructs an inverted index mapping tokens to concept indices.
        :return: A dictionary with tokens as keys and lists of concept indices as values.
        """
        index = defaultdict(list)  # Initialize an empty inverted index
        for concept_id, labels in self.ontotext.texts.items():
            tokens = self.tokenize(labels)  # Tokenize all labels/synonyms
            for token in tokens:
                if len(token) > self.cut:  # Include tokens that meet the length threshold
                    index[token].append(self.ontotext.class2idx[concept_id])  # Map token to concept index
        return index


# Class to manage source and target ontology data and generate mapping candidates
class OntoBox:
    def __init__(self, src_data, tgt_data, tokenizer_path="cambridgeltl/SapBERT-UMLS-2020AB-all-lang-from-XLMR", cut=0):
        """
        Initialize the OntoBox class with source and target ontologies.
        :param src_data: Source ontology data (concept IDs and labels/synonyms).
        :param tgt_data: Target ontology data (concept IDs and labels/synonyms).
        :param tokenizer_path: Path to a pre-trained tokenizer.
        :param cut: Minimum token length for the inverted index.
        """
        self.src_ontotext = OntoText(src_data)  # Process source ontology data
        self.tgt_ontotext = OntoText(tgt_data)  # Process target ontology data
        # Create inverted indices for both source and target ontologies
        self.src_onto_index = OntoInvertedIndex(self.src_ontotext, tokenizer_path, cut=cut)
        self.tgt_onto_index = OntoInvertedIndex(self.tgt_ontotext, tokenizer_path, cut=cut)

    def select_candidates(self, concept_texts: List[str], candidate_limit: int = 10):
        """
        Select candidate concepts from the target ontology based on token overlap and IDF scores.
        :param concept_texts: List of source concept labels/synonyms to find matches for.
        :param candidate_limit: Maximum number of candidates to return.
        :return: List of candidate concept IDs from the target ontology.
        """
        candidate_pool = defaultdict(lambda: 0)  # Pool of candidate scores
        tokens = self.tgt_onto_index.tokenize(concept_texts)  # Tokenize source concept texts
        D = len(self.tgt_ontotext.class2idx)  # Total number of target concepts

        for token in tokens:
            potential_candidates = self.tgt_onto_index.index.get(token, [])  # Get concepts containing the token
            if not potential_candidates:
                continue
            # Calculate Inverse Document Frequency (IDF) for the token
            idf = math.log10(D / len(potential_candidates))
            for class_id in potential_candidates:
                candidate_pool[class_id] += idf  # Accumulate IDF scores for candidates

        # Sort candidates by score (descending) and limit to the specified number
        sorted_candidates = sorted(candidate_pool.items(), key=lambda x: x[1], reverse=True)[:candidate_limit]
        # Retrieve the original concept IDs for the selected candidates
        selected_classes = [self.tgt_ontotext.idx2class[c[0]] for c in sorted_candidates]

        return selected_classes

    def generate_candidates(self, candidate_limit: int = 10):
        """
        Generate candidate mappings between source and target ontologies.
        :param candidate_limit: Maximum number of candidates per source concept.
        :return: List of candidate pairs (source concept ID, target concept ID).
        """
        candidate_pairs = []
        # Iterate through all source concepts
        for src_id, text_dict in self.src_ontotext.texts.items():
            src_texts = text_dict  # Use all source labels/synonyms
            candidates = self.select_candidates(src_texts, candidate_limit)  # Get target candidates
            # Pair each source concept with its selected target candidates
            for tgt_id in candidates:
                candidate_pairs.append((src_id, tgt_id))

        return candidate_pairs

# %%
def clean_json_by_alignment(file_path, json_path, output_path):
    """
    Cleans a JSON file by removing concepts marked as not used for alignment.

    Args:
        file_path (str): Path to the OWL file (ontology in RDF/XML format).
        json_path (str): Path to the JSON file to clean.
        output_path (str): Path to save the cleaned JSON file.
    """
    # Initialize the RDF graph
    g = Graph()
    # Parse the OWL file into the RDF graph
    g.parse(file_path, format='xml')

    # Define namespaces for the RDF graph
    ALIGNMENT_NS = Namespace("http://oaei.ontologymatching.org/bio-ml/ann/")
    # Define the specific property used to indicate alignment usability
    USE_IN_ALIGNMENT = URIRef("http://oaei.ontologymatching.org/bio-ml/ann/use_in_alignment")

    # Load the JSON file containing concepts and labels/synonyms
    with open(json_path, "r") as f:
        data = json.load(f)

    # Set to hold valid IRIs (concepts marked as usable for alignment)
    valid_iris = set()

    # Iterate over all subjects (classes) in the ontology
    for subj in g.subjects(predicate=None):
        # Check if the class has a `use_in_alignment` annotation
        alignment_value = g.value(subject=subj, predicate=USE_IN_ALIGNMENT)
        # Include the IRI if `use_in_alignment` is not present or is set to "true"
        if alignment_value is None or str(alignment_value).lower() == "true":
            valid_iris.add(str(subj))

    # Filter the JSON data to include only IRIs present in the valid set
    cleaned_data = {iri: labels for iri, labels in data.items() if iri in valid_iris}

    # Save the cleaned JSON data to the specified output file
    with open(output_path, "w") as f:
        json.dump(cleaned_data, f, indent=4, ensure_ascii=False)

    # Print summary information about the cleaning process
    print(f"Cleaned JSON file saved to: {output_path}")
    print(f"Excluded concepts: {len(data) - len(cleaned_data)}")
    print(f"Remaining concepts: {len(cleaned_data)}")

# %%
def clean_json_using_tsv(json_file_path, tsv_file_path, output_json_path):
    """
    Cleans a JSON file by removing entries not present in the 'SrcEntity' column of a TSV file.

    Args:
    - json_file_path (str): Path to the JSON file to be cleaned.
    - tsv_file_path (str): Path to the TSV file containing valid 'SrcEntity' entries.
    - output_json_path (str): Path to save the cleaned JSON file.

    Returns:
    - None
    """
    # Load the JSON file
    with open(json_file_path, 'r') as json_file:
        json_data = json.load(json_file)

    # Load the TSV file and extract 'SrcEntity' column as a set
    tsv_data = pd.read_csv(tsv_file_path, sep="\t")
    valid_entities = set(tsv_data['SrcEntity'])

    # Filter JSON entries to retain only those keys present in 'SrcEntity'
    original_count = len(json_data)
    cleaned_data = {key: value for key, value in json_data.items() if key in valid_entities}
    cleaned_count = len(cleaned_data)

    # Calculate excluded entries
    excluded_count = original_count - cleaned_count

    # Save the cleaned JSON data
    with open(output_json_path, 'w') as output_file:
        json.dump(cleaned_data, output_file, indent=4)

    print(f"Cleaned JSON file saved to {output_json_path}")
    print(f"Original entries: {original_count}")
    print(f"Remaining entries: {cleaned_count}")
    print(f"Excluded entries: {excluded_count}")

# %%
# Function to build indexed dictionary
def build_indexed_dict(file_path):
    # Load the JSON file
    with open(file_path, 'r') as file:
        data = json.load(file)

    # Create a new dictionary with numeric indexes for each key (URI)
    indexed_dict = {key: index for index, key in enumerate(data.keys())}

    return indexed_dict

# %%
# Function to encode URIs using the provided indexed dictionaries
def encode_uris(row, source_dict, target_dict):
    """
    Encodes URIs from a DataFrame row using provided dictionaries.

    Args:
        row (pd.Series): A single row from a DataFrame containing `SrcEntity` and `TgtEntity` columns.
        source_dict (dict): Dictionary mapping source URIs to their integer encodings.
        target_dict (dict): Dictionary mapping target URIs to their integer encodings.

    Returns:
        pd.Series: A series containing the encoded source and target URIs as integers.
    """
    # Extract source and target URIs from the row
    uri_1, uri_2 = row['SrcEntity'], row['TgtEntity']

    # Encode the source URI using the source dictionary, defaulting to -1 if not found
    encoded_uri_1 = source_dict.get(uri_1, -1)  # -1 indicates a missing value
    # Encode the target URI using the target dictionary, defaulting to -1 if not found
    encoded_uri_2 = target_dict.get(uri_2, -1)  # -1 indicates a missing value

    # Ensure the encoded URIs are integers (in case they are stored as floats or other types)
    return pd.Series([int(encoded_uri_1), int(encoded_uri_2)])

# %%
# Define the source ontology name
src_ent = "snomed.body"

# Define the target ontology name
tgt_ent = "fma.body"

# Define the task name for this ontology matching process
task = "body"

# %%
dir = "../"

# Define the directory for the dataset containing source and target ontologies
dataset_dir = f"{dir}/Datasets/{task}"

# Define the data directory for storing embeddings, adjacency matrices, and related files
data_dir = f"{dir}/{task}/Data"

# %%
# Load the Source ontology (OMIM) using the Ontology class from DeepOnto
src_onto_path = f"{dataset_dir}/{src_ent}.owl"

# Load the Target ontology (ORDO) using the Ontology class from DeepOnto
tgt_onto_path = f"{dataset_dir}/{tgt_ent}.owl"

# Define the file path for the JSON file containing the Source ontology (OMIM) class labels
src_class_path = f"{data_dir}/{src_ent}_classes.json"

# Define the file path for the JSON file containing the Target ontology (ORDO) class labels
tgt_class_path = f"{data_dir}/{tgt_ent}_classes.json"

# Define the file path for the candidate mappings between Source to Target entities
Candidates = f"{data_dir}/{task}_candidates.csv"

# Define the file path for the cleaned JSON file containing source class labels used for testing
src_class_cleaned_test = f"{data_dir}/{src_ent}_cleaned_test_classes.json"  # Cleaned test classes for source

# Define the file path for the TSV file containing reference equivalences for testing
tsv_file_path = f"{dataset_dir}/refs_equiv/test.tsv"  # Reference file with equivalences for evaluation

# Define the file path for the cleaned and encoded JSON file containing source class labels
src_class_cleaned = f"{data_dir}/{src_ent}_cleaned_classes.json"  # Cleaned and encoded classes for source

# Define the file path for the cleaned JSON file containing target class labels
tgt_class_cleaned = f"{data_dir}/{tgt_ent}_cleaned_classes.json"  # Cleaned classes for target

# Define the file paths for candidate mappings
candidate_path = f"{data_dir}/candidates_cleaned.csv"  # CSV file with candidate mappings

candidate_encoded_path = f"{data_dir}/{task}_candidates_cleaned_encoded.csv"  # Encoded candidate mappings

candidates_cleaned_encoded_combined = f"{data_dir}/{task}_candidates_cleaned_combined_encoded.csv"

candidates_cleaned_encoded_enriched = f"{data_dir}/{task}_candidates_cleaned_enriched_encoded.csv"

# %% [markdown]
# # **Cleaning**

# %%
# Clean the JSON file for the source ontology
# This removes unnecessary concepts from the source ontology JSON file (`src_class_path`)
# based on alignment annotations in the source ontology OWL file (`src_onto_path`).
# The cleaned JSON is saved to `src_class_cleaned_encodage`.
clean_json_by_alignment(src_onto_path, src_class_path, src_class_cleaned)

# Clean the JSON file for the target ontology
# Similarly, this removes unnecessary concepts from the target ontology JSON file (`tgt_class_path`)
# based on alignment annotations in the target ontology OWL file (`tgt_onto_path`).
# The cleaned JSON is saved to `tgt_class_cleaned`.
clean_json_by_alignment(tgt_onto_path, tgt_class_path, tgt_class_cleaned)
# Out:
# Cleaned JSON file saved to: /content/gdrive/My Drive/BioGITOM-VLDB//body/Data/snomed.body_cleaned_classes.json
# Excluded concepts: 10236
# Remaining concepts: 24318
# Cleaned JSON file saved to: /content/gdrive/My Drive/BioGITOM-VLDB//body/Data/fma.body_cleaned_classes.json
# Excluded concepts: 24229
# Remaining concepts: 64890

# %%
# Call the function to clean the source JSON file based on the TSV file
# The `clean_json_using_tsv` function uses the reference equivalence file (`tsv_file_path`)
# to further filter the cleaned source JSON file (`src_class_cleaned_encodage`).
# The resulting JSON file, containing only relevant concepts for testing, is saved to `src_class_cleaned_test`.
clean_json_using_tsv(src_class_cleaned, tsv_file_path, src_class_cleaned_test)
# Out:
# Cleaned JSON file saved to /content/gdrive/My Drive/BioGITOM-VLDB//body/Data/snomed.body_cleaned_test_classes.json
# Original entries: 24318
# Remaining entries: 4604
# Excluded entries: 19714

# %% [markdown]
# # **Candidates Generation**

# %%
# Load JSON files for both source and target ontologies
with open(src_class_cleaned_test, 'r') as f:
    src_data = json.load(f)

# Assuming the target data JSON file path is correct
with open(tgt_class_cleaned, 'r') as f:
    tgt_data = json.load(f)

# %%
# Instantiate OntoBox and generate candidate pairs
ontobox = OntoBox(src_data, tgt_data)
candidates = ontobox.generate_candidates()

# Print candidates for verification
for src, tgt in candidates:
    print(f"SrcEntity: {src}, TgtEntity: {tgt}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma76785
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma45063
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma48264
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma45081
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma45084
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma45075
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma43794
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma45067
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma45066
# SrcEntity: http://snomed.info/id/289075000, TgtEntity: http://purl.org/sig/ont/fma/fma45068
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma17735
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma17736
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma66611
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma66612
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma72006
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma15604
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma72007
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma15605
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma74303
# SrcEntity: http://snomed.info/id/64033007, TgtEntity: http://purl.org/sig/ont/fma/fma74304
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma72622
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma62162
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma72483
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma72484
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma54533
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma62037
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma62156
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma62329
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma72435
# SrcEntity: http://snomed.info/id/29762003, TgtEntity: http://purl.org/sig/ont/fma/fma62202
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma69225
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma69231
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma69230
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma15646
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma15633
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma15632
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma69090
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma15631
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma69806
# SrcEntity: http://snomed.info/id/21476003, TgtEntity: http://purl.org/sig/ont/fma/fma9598
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma71418
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma71419
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma71414
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma72500
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma71422
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma44279
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma44280
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma44269
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma71412
# SrcEntity: http://snomed.info/id/233474004, TgtEntity: http://purl.org/sig/ont/fma/fma71415
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma50248
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma71817
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma71836
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma71818
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma17663
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma17662
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma17926
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma50205
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma50207
# SrcEntity: http://snomed.info/id/102290008, TgtEntity: http://purl.org/sig/ont/fma/fma50206
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma71302
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma50223
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma22732
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma22731
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma281254
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma50225
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma50224
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma277390
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma5980
# SrcEntity: http://snomed.info/id/44947003, TgtEntity: http://purl.org/sig/ont/fma/fma5979
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma7478
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma71784
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma71762
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma52973
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma52895
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma52888
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma52887
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma52886
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma52910
# SrcEntity: http://snomed.info/id/47173002, TgtEntity: http://purl.org/sig/ont/fma/fma75665
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma281254
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma277390
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma71784
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma71777
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma277395
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma278001
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma73251
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma73257
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma233577
# SrcEntity: http://snomed.info/id/91659002, TgtEntity: http://purl.org/sig/ont/fma/fma278150
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37627
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37639
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37615
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37651
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37630
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37523
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37537
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37633
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37513
# SrcEntity: http://snomed.info/id/263425009, TgtEntity: http://purl.org/sig/ont/fma/fma37511
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma72065
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma8832
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma8766
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma8765
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma8833
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma8831
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma8764
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma278001
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma16197
# SrcEntity: http://snomed.info/id/77268005, TgtEntity: http://purl.org/sig/ont/fma/fma17675
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma62156
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma74867
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma311309
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma311323
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma62162
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma62202
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma62186
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma62019
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma56498
# SrcEntity: http://snomed.info/id/75551009, TgtEntity: http://purl.org/sig/ont/fma/fma61151
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma61113
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma19702
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma71788
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma72485
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma61114
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma74960
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma45694
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma61115
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma75276
# SrcEntity: http://snomed.info/id/81955007, TgtEntity: http://purl.org/sig/ont/fma/fma71785
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma8819
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma8820
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma8821
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma72064
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma62469
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma62470
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma293652
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma293649
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma10027
# SrcEntity: http://snomed.info/id/28232001, TgtEntity: http://purl.org/sig/ont/fma/fma28730
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma15932
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma15928
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma15930
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma15914
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma15908
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma15912
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma15931
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma17854
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma17853
# SrcEntity: http://snomed.info/id/250930003, TgtEntity: http://purl.org/sig/ont/fma/fma15929
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma71711
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma3860
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma3840
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma71678
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma46758
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma79404
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma79405
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma79406
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma75246
# SrcEntity: http://snomed.info/id/33102007, TgtEntity: http://purl.org/sig/ont/fma/fma75247
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma281254
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma277390
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma71777
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma277395
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma44678
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma71823
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma233577
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma16905
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma16906
# SrcEntity: http://snomed.info/id/32293005, TgtEntity: http://purl.org/sig/ont/fma/fma16902
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma43612
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma43613
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma75665
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma76554
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma77765
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma258693
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma75735
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma43614
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma44580
# SrcEntity: http://snomed.info/id/304679005, TgtEntity: http://purl.org/sig/ont/fma/fma44661
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma7811
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma8203
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma7804
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma8176
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma8797
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma8798
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma8731
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma8811
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma8732
# SrcEntity: http://snomed.info/id/82783003, TgtEntity: http://purl.org/sig/ont/fma/fma8812
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma33739
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma33730
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma33729
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma33740
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma33738
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma33731
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma34030
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma33987
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma34012
# SrcEntity: http://snomed.info/id/724230007, TgtEntity: http://purl.org/sig/ont/fma/fma34005
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma277390
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma7253
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma7254
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma7252
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma9502
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma9365
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma71776
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma281254
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma3740
# SrcEntity: http://snomed.info/id/15825003, TgtEntity: http://purl.org/sig/ont/fma/fma16604
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma45084
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma43794
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma33640
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma45086
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma45085
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma45081
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma16900
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma76642
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma322236
# SrcEntity: http://snomed.info/id/81210008, TgtEntity: http://purl.org/sig/ont/fma/fma18317
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma15077
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma45769
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma19733
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma15078
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma77881
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma21930
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma14915
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma27335
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma27341
# SrcEntity: http://snomed.info/id/51807001, TgtEntity: http://purl.org/sig/ont/fma/fma49345
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma54645
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma54651
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma54665
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma281528
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma54644
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma71289
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma322961
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma58342
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma281543
# SrcEntity: http://snomed.info/id/23263000, TgtEntity: http://purl.org/sig/ont/fma/fma281551
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma8619
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma49912
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma3840
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma8647
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma8632
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma8663
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma49917
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma8620
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma8627
# SrcEntity: http://snomed.info/id/369311002, TgtEntity: http://purl.org/sig/ont/fma/fma3860
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma71336
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma42790
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma42789
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma36253
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma36290
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma36254
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma36292
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma36279
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma36291
# SrcEntity: http://snomed.info/id/368509002, TgtEntity: http://purl.org/sig/ont/fma/fma36278
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma8826
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma8825
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma8827
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma11380
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma11382
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma11381
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma72064
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma10076
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma10078
# SrcEntity: http://snomed.info/id/74366003, TgtEntity: http://purl.org/sig/ont/fma/fma9156
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma6233
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma5988
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma53483
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma16729
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma16728
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma11226
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma16715
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma11143
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma16718
# SrcEntity: http://snomed.info/id/22889004, TgtEntity: http://purl.org/sig/ont/fma/fma11222
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma311216
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma47155
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma61840
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma75665
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma76554
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma77765
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma258693
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma75735
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma62162
# SrcEntity: http://snomed.info/id/78376008, TgtEntity: http://purl.org/sig/ont/fma/fma54533
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8678
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8663
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8670
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8662
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8692
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8675
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8682
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8694
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8686
# SrcEntity: http://snomed.info/id/39484005, TgtEntity: http://purl.org/sig/ont/fma/fma8666
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma59375
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma286142
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma68116
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma55813
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma24765
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma56696
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma56669
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma56687
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma56678
# SrcEntity: http://snomed.info/id/16251004, TgtEntity: http://purl.org/sig/ont/fma/fma56699
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma321009
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma321011
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma321010
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma20173
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma20174
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma19618
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma321005
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma321008
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma321007
# SrcEntity: http://snomed.info/id/9284003, TgtEntity: http://purl.org/sig/ont/fma/fma321006
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma71807
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma71197
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma14997
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma15683
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma303746
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma303748
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma71198
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma14995
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma14994
# SrcEntity: http://snomed.info/id/38781007, TgtEntity: http://purl.org/sig/ont/fma/fma14991
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma55030
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma6233
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma53474
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma55064
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma53487
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma53497
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma53496
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma55036
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma46661
# SrcEntity: http://snomed.info/id/88399001, TgtEntity: http://purl.org/sig/ont/fma/fma53475
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma281254
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma277390
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma71784
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma277395
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma71777
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma84599
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma71823
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma278001
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma277397
# SrcEntity: http://snomed.info/id/245362002, TgtEntity: http://purl.org/sig/ont/fma/fma16607
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma74272
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma15849
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma15626
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma58273
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma27984
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma69225
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma61958
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma34944
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma64125
# SrcEntity: http://snomed.info/id/91765006, TgtEntity: http://purl.org/sig/ont/fma/fma39444
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma71413
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma71417
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma44207
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma24519
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma34979
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma72500
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma71399
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma71422
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma71418
# SrcEntity: http://snomed.info/id/6606008, TgtEntity: http://purl.org/sig/ont/fma/fma71414
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma84035
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma74034
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma321544
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma321545
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma72356
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma71871
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma75450
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma77199
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma61884
# SrcEntity: http://snomed.info/id/360464007, TgtEntity: http://purl.org/sig/ont/fma/fma61891
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma19860
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma19814
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma19944
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma19943
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma19942
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma75665
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma76554
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma77765
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma75735
# SrcEntity: http://snomed.info/id/40689003, TgtEntity: http://purl.org/sig/ont/fma/fma19849
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma53474
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma53475
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma6233
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma53483
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma53487
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma53497
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma53496
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma46647
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma50870
# SrcEntity: http://snomed.info/id/244451008, TgtEntity: http://purl.org/sig/ont/fma/fma72627
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma72065
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma16215
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma16128
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma9155
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma293673
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma16137
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma16131
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma16129
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma16132
# SrcEntity: http://snomed.info/id/79390004, TgtEntity: http://purl.org/sig/ont/fma/fma16130
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma281254
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma277390
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma71784
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma71793
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma84599
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma277271
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma77165
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma12784
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma277264
# SrcEntity: http://snomed.info/id/23198005, TgtEntity: http://purl.org/sig/ont/fma/fma276813
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma59377
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma77765
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma59819
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma61869
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma75665
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma76554
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma258693
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma75735
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma6233
# SrcEntity: http://snomed.info/id/84365009, TgtEntity: http://purl.org/sig/ont/fma/fma37693
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma35719
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma35694
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma35554
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma35578
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma34567
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma35834
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma34592
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma35693
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma35553
# SrcEntity: http://snomed.info/id/272722001, TgtEntity: http://purl.org/sig/ont/fma/fma35718
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma8663
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma8686
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma8670
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma8694
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma8682
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma71761
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma8692
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma8661
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma8664
# SrcEntity: http://snomed.info/id/368061007, TgtEntity: http://purl.org/sig/ont/fma/fma8684
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma31723
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma71824
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma16645
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma6799
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma6030
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma71835
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma8781
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma8780
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma8852
# SrcEntity: http://snomed.info/id/26359000, TgtEntity: http://purl.org/sig/ont/fma/fma8786
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma13365
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma14501
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma15739
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma8665
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma62156
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma7360
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma62218
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma15810
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma7505
# SrcEntity: http://snomed.info/id/16777006, TgtEntity: http://purl.org/sig/ont/fma/fma15742
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma15684
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma60109
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma62996
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma15678
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma15676
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma15672
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma15656
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma15674
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma15680
# SrcEntity: http://snomed.info/id/370140002, TgtEntity: http://purl.org/sig/ont/fma/fma15687
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma62037
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma54533
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma62162
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma62156
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma62329
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma62202
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma72435
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma54611
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma62346
# SrcEntity: http://snomed.info/id/45013007, TgtEntity: http://purl.org/sig/ont/fma/fma54504
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma75665
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma76554
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma77765
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma258693
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma75735
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma62097
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma8686
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma8682
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma71433
# SrcEntity: http://snomed.info/id/73056007, TgtEntity: http://purl.org/sig/ont/fma/fma8684
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma15683
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma62469
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma62470
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma15651
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma15657
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma277641
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma277627
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma70927
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma70809
# SrcEntity: http://snomed.info/id/14128009, TgtEntity: http://purl.org/sig/ont/fma/fma60106
# SrcEntity: http://snomed.info/id/211187004, TgtEntity: http://purl.org/sig/ont/fma/fma43794
# SrcEntity: http://snomed.info/id/211187004, TgtEntity: http://purl.org/sig/ont/fma/fma45198
# SrcEntity: http://snomed.info/id/211187004, TgtEntity: http://purl.org/sig/ont/fma/fma45081
# SrcEntity: http://snomed.info/id/211187004, TgtEntity: http://purl.org/sig/ont/fma/fma45084
# SrcEntity: http://snomed.info/id/211187004, TgtEntity: http://purl.org/sig/ont/fma/fma45086
# SrcEntity: http://snomed.info/id/211187004, TgtEntity: http://purl.org/sig/ont/fma/fma45085
# SrcEntity: http://snomed.info/id/211187004, TgtEntity: http://purl.org/sig/ont/fma/fma45049
# ...
# SrcEntity: http://snomed.info/id/35378004, TgtEntity: http://purl.org/sig/ont/fma/fma15841
# SrcEntity: http://snomed.info/id/35378004, TgtEntity: http://purl.org/sig/ont/fma/fma15848
# SrcEntity: http://snomed.info/id/35378004, TgtEntity: http://purl.org/sig/ont/fma/fma15850
# SrcEntity: http://snomed.info/id/35378004, TgtEntity: http://purl.org/sig/ont/fma/fma18652
# SrcEntity: http://snomed.info/id/35378004, TgtEntity: http://purl.org/sig/ont/fma/fma280919
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma18641
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma70935
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma70736
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma70996
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma18640
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma70679
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma15843
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma70666
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma70772
# SrcEntity: http://snomed.info/id/67290009, TgtEntity: http://purl.org/sig/ont/fma/fma18643
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma7243
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma7135
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma7242
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma19640
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma61842
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma8684
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma59490
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma59447
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma59544
# SrcEntity: http://snomed.info/id/90040008, TgtEntity: http://purl.org/sig/ont/fma/fma61845
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8663
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8665
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8686
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8692
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8682
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8694
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8664
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8684
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8678
# SrcEntity: http://snomed.info/id/40880001, TgtEntity: http://purl.org/sig/ont/fma/fma8670
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma19733
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma69918
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma15938
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma27335
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma27341
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma49345
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma7243
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma7242
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma71649
# SrcEntity: http://snomed.info/id/279474003, TgtEntity: http://purl.org/sig/ont/fma/fma19676
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma55609
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma55608
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma46777
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma53374
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma53373
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma53370
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma47357
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma47356
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma47359
# SrcEntity: http://snomed.info/id/44866004, TgtEntity: http://purl.org/sig/ont/fma/fma47361
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma61734
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma61305
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma70748
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma61313
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma61298
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma61312
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma61306
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma61307
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma61310
# SrcEntity: http://snomed.info/id/86409001, TgtEntity: http://purl.org/sig/ont/fma/fma53198
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37639
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37523
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37615
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37627
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37651
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37645
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37537
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37525
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37524
# SrcEntity: http://snomed.info/id/263426005, TgtEntity: http://purl.org/sig/ont/fma/fma37638
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma7383
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma7371
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma7374
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma8692
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma8694
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma7375
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma8690
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma7370
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma8686
# SrcEntity: http://snomed.info/id/362899007, TgtEntity: http://purl.org/sig/ont/fma/fma8682
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma8775
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma8840
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma8774
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma8842
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma8841
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma8773
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma72065
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma17595
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma17570
# SrcEntity: http://snomed.info/id/80076006, TgtEntity: http://purl.org/sig/ont/fma/fma17682
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma34687
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma50223
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma50225
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma50224
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma71748
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma34696
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma38158
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma224534
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma224536
# SrcEntity: http://snomed.info/id/2192001, TgtEntity: http://purl.org/sig/ont/fma/fma34699
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma55416
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma55417
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma55418
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma74634
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma56498
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma74867
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma311309
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma52910
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma27984
# SrcEntity: http://snomed.info/id/303403006, TgtEntity: http://purl.org/sig/ont/fma/fma16215
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma23065
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma35283
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma35284
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma35282
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma45084
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma43794
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma23069
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma23068
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma45086
# SrcEntity: http://snomed.info/id/8039003, TgtEntity: http://purl.org/sig/ont/fma/fma45085
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma74510
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma21860
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma10420
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma37693
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma19473
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma6233
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma77765
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma265269
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma15855
# SrcEntity: http://snomed.info/id/343011009, TgtEntity: http://purl.org/sig/ont/fma/fma8686
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma21491
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma39447
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma75665
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma76554
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma77765
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma258693
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma75735
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma25058
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma293598
# SrcEntity: http://snomed.info/id/84694005, TgtEntity: http://purl.org/sig/ont/fma/fma293592
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma37657
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma37645
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma37633
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma37621
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma33106
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma33036
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma36253
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma34427
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma36254
# SrcEntity: http://snomed.info/id/306716003, TgtEntity: http://purl.org/sig/ont/fma/fma36279
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma61908
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma61965
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma62502
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma72358
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma72968
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma72967
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma61893
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma67966
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma61859
# SrcEntity: http://snomed.info/id/27140001, TgtEntity: http://purl.org/sig/ont/fma/fma61896
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma14936
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma14935
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma15709
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma15651
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma14938
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma15699
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma15036
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma14937
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma14994
# SrcEntity: http://snomed.info/id/59150006, TgtEntity: http://purl.org/sig/ont/fma/fma15022

# %%
# Convert candidates to a DataFrame
candidate_df = pd.DataFrame(candidates, columns=["SrcEntity", "TgtEntity"])

# Add an incremental "ID" column starting from 0
candidate_df.insert(0, "ID", range(len(candidate_df)))

# Save the DataFrame to a CSV file
candidate_df.to_csv(candidate_path, index=False)

print(f"Candidates saved successfully to {candidate_path}")
# Out:
# Candidates saved successfully to /content/gdrive/My Drive/BioGITOM-VLDB//body/Data/candidates_cleaned.csv

# %%
# Load Source and Target and ORDO class indexed dictionaries
indexed_dict_source = build_indexed_dict(src_class_path)
indexed_dict_target = build_indexed_dict(tgt_class_path)

# %%
# Create a DataFrame from the list of candidate mappings
# The `candidates` variable is expected to be a list of tuples containing source and target entities.
candidate_df = pd.DataFrame(candidates, columns=["SrcEntity", "TgtEntity"])

# Apply the `encode_uris` function to encode the source and target URIs into integers
# The `source_dict` and `target_dict` are dictionaries mapping URIs to their integer indices.
# This ensures the URIs are replaced with numeric representations in the DataFrame.
candidate_df[["SrcEntity", "TgtEntity"]] = candidate_df.apply(
    encode_uris, axis=1, source_dict=indexed_dict_source, target_dict=indexed_dict_target
)

# Add an ID column to the DataFrame
# The ID column is a unique identifier for each candidate pair, starting from 1.
candidate_df["ID"] = candidate_df.index + 1

# Reorder the columns for the final output: ID, SrcEntity, TgtEntity
# Save the DataFrame to a CSV file with the specified `candidate_encoded_path`.
# The `quoting=csv.QUOTE_NONNUMERIC` ensures that numeric values are not enclosed in quotes.
candidate_df[["ID", "SrcEntity", "TgtEntity"]].to_csv(candidate_encoded_path, index=False, quoting=csv.QUOTE_NONNUMERIC)

# Print confirmation message with the file path
print(f"Candidates saved to {candidate_encoded_path}")
# Out:
# Candidates saved to /content/gdrive/My Drive/BioGITOM-VLDB//body/Data/body_candidates_cleaned_encoded.csv

# %%
# Load the existing candidates file
candidates_df = pd.read_csv(candidate_encoded_path)

# Load the source file with additional candidates
additional_candidates_df = pd.read_csv(Candidates)

# Concatenate the two DataFrames
combined_df = pd.concat([candidates_df, additional_candidates_df])

# Remove duplicate rows based on SrcEntity and TgtEntity columns
combined_df = combined_df.drop_duplicates(subset=["SrcEntity", "TgtEntity"])

# Save the combined DataFrame back to a CSV file
combined_df.to_csv(candidates_cleaned_encoded_combined, index=False, quoting=csv.QUOTE_NONNUMERIC)

print(f"Combined candidates saved to {candidates_cleaned_encoded_combined}")
# Out:
# Combined candidates saved to /content/gdrive/My Drive/BioGITOM-VLDB//body/Data/body_candidates_cleaned_combined_encoded.csv

# %%
# Load the existing candidates file
candidates_df = pd.read_csv(candidate_encoded_path)

# Load the source file with additional candidates
additional_candidates_df = pd.read_csv(Candidates)

# Identify entries in the additional candidates file that are not in the existing candidates file
# Assuming 'SrcEntity' and 'TgtEntity' columns are used to uniquely identify rows
new_entries = additional_candidates_df[
    ~additional_candidates_df.set_index(["SrcEntity", "TgtEntity"]).index.isin(
        candidates_df.set_index(["SrcEntity", "TgtEntity"]).index
    )
]

# Append the new entries to the original candidates DataFrame
enriched_candidates_df = pd.concat([candidates_df, new_entries])

# Save the enriched DataFrame to a new file or overwrite the original file
enriched_candidates_df.to_csv(candidates_cleaned_encoded_enriched, index=False, quoting=csv.QUOTE_NONNUMERIC)

print(f"Enriched candidates saved to {candidates_cleaned_encoded_enriched}")
# Out:
# Enriched candidates saved to /content/gdrive/My Drive/BioGITOM-VLDB//body/Data/body_candidates_cleaned_enriched_encoded.csv
